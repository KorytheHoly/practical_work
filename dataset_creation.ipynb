# %%
import yfinance as yf
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from IPython.display import display, HTML


sns.set(rc={'figure.figsize':(9,4.5)})

# %%
data = yf.download("MSFT", start="2010-01-01", end="2022-04-30", interval= '1d')
df = pd.DataFrame(data)
df.columns = [i.lower() for i in df.columns]
display(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   open        high         low       close   adj close  \
# Date
# 2010-01-04   30.620001   31.100000   30.590000   30.950001   23.683075
# 2010-01-05   30.850000   31.100000   30.639999   30.959999   23.690720
# 2010-01-06   30.879999   31.080000   30.520000   30.770000   23.545328
# 2010-01-07   30.629999   30.700001   30.190001   30.450001   23.300461
# 2010-01-08   30.280001   30.879999   30.240000   30.660000   23.461164
# ...                ...         ...         ...         ...         ...
# 2022-04-25  273.290009  281.109985  270.769989  280.720001  278.689087
# 2022-04-26  277.500000  278.359985  270.000000  270.220001  268.265076
# 2022-04-27  282.100006  290.970001  279.160004  283.220001  281.170990
# 2022-04-28  285.190002  290.980011  281.459991  289.630005  287.534637
# 2022-04-29  288.609985  289.880005  276.500000  277.519989  275.512238
#
#               volume
# Date
# 2010-01-04  38409100
# 2010-01-05  49749600
# 2010-01-06  58182400
# 2010-01-07  50559700
# 2010-01-08  51197400
# ...              ...
# 2022-04-25  35678900
# 2022-04-26  46518400
# 2022-04-27  63477700
# 2022-04-28  33646600
# 2022-04-29  37073900
#
# [3103 rows x 6 columns]

# %%
for name in df.columns[1:]:
    df[f'{name}_per'] = df[name].pct_change()
df.head()
# Out:
#                  open       high        low      close  adj close    volume  \
# Date
# 2010-01-04  30.620001  31.100000  30.590000  30.950001  23.683075  38409100
# 2010-01-05  30.850000  31.100000  30.639999  30.959999  23.690720  49749600
# 2010-01-06  30.879999  31.080000  30.520000  30.770000  23.545328  58182400
# 2010-01-07  30.629999  30.700001  30.190001  30.450001  23.300461  50559700
# 2010-01-08  30.280001  30.879999  30.240000  30.660000  23.461164  51197400
#
#             high_per   low_per  close_per  adj close_per  volume_per
# Date
# 2010-01-04       NaN       NaN        NaN            NaN         NaN
# 2010-01-05  0.000000  0.001634   0.000323       0.000323    0.295256
# 2010-01-06 -0.000643 -0.003916  -0.006137      -0.006137    0.169505
# 2010-01-07 -0.012226 -0.010813  -0.010400      -0.010400   -0.131014
# 2010-01-08  0.005863  0.001656   0.006897       0.006897    0.012613

# %%
sns.lineplot(df,x='Date', y='open')
plt.show()
